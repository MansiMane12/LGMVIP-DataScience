# %% [markdown]
# **Data Science Intern**  **@ LetsGrowMore Virtual Internship**
# **Name :Mansi Sunil Mane**
#
# **Task 1 ( Beginner Level Task )**
#
# **Image To Pencil Sketch With Python**
#
# **Import the library**

# %% [markdown]
# **IMPORTING THE REQUIRED LIBRARIES**

# %%
import cv2
import matplotlib.pyplot as plt
from google.colab.patches import cv2_imshow

# %% [markdown]
# **READING THE IMAGE IN BGR FORMAT**

# %%
image = cv2.imread("/content/flower_1.jpg")
o_image =cv2.resize(image, (500, 800))
cv2_imshow(o_image)
# Out:
# <PIL.Image.Image image mode=RGB size=500x800 at 0x7FAC07AA77D0>

# %% [markdown]
# **CONVERTING A BGR IMAGE INTO RGB IMAGE**

# %%
rgbimg = cv2.cvtColor(o_image, cv2.COLOR_BGR2RGB)
cv2_imshow(rgbimg)
# Out:
# <PIL.Image.Image image mode=RGB size=500x800 at 0x7FABF9F54F10>

# %% [markdown]
# **CONVERTING RGB IMAGE INTO GRAYSCALE IMAGE**

# %%
grayimg = cv2.cvtColor(rgbimg, cv2.COLOR_RGB2GRAY)
cv2_imshow(grayimg)
# Out:
# <PIL.Image.Image image mode=L size=500x800 at 0x7FABF9F64450>

# %% [markdown]
# **INVERTING THE IMAGE**

# %%
invertimg = cv2.bitwise_not(grayimg)
cv2_imshow(invertimg)
# Out:
# <PIL.Image.Image image mode=L size=500x800 at 0x7FABF9F64D10>

# %% [markdown]
# **BLURRING THE IMAGE**

# %%
blurimg= cv2.GaussianBlur(invertimg, (15, 15), sigmaX=0, sigmaY=0)
cv2_imshow(blurimg)
# Out:
# <PIL.Image.Image image mode=L size=500x800 at 0x7FABF9F6BC90>

# %% [markdown]
# **PENCIL SKETCH**

# %%
pencil_sketch = cv2.divide(grayimg, 255 - blurimg, scale=256)
cv2_imshow(pencil_sketch)
# Out:
# <PIL.Image.Image image mode=L size=500x800 at 0x7FABF8EF16D0>

# %% [markdown]
# **ORIGNAL IMAGE AND PENCIL SKETCH**

# %%
cv2_imshow(o_image)
cv2_imshow(pencil_sketch)
# Out:
# <PIL.Image.Image image mode=RGB size=500x800 at 0x7FABF8EFAC50>
# <PIL.Image.Image image mode=L size=500x800 at 0x7FABF8EFAA90>

# %% [markdown]
# **The flower image is converted into pencil sketch with cv2 library in python.**
#
# **END OF TASK 1**
#
# **THANK YOU!!!**
