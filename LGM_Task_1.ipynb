# %% [markdown]
# **Data Science Intern  @ LetsGrowMore Virtual Internship**
#    **Name :Mansi Sunil Mane**
#
# **Task 1 ( Beginner Level Task )**
#
# **Image To Pencil Sketch With Python**
#
# **Import the library**

# %%
import cv2
import matplotlib.pyplot as plt
from google.colab.patches import cv2_imshow

# %% [markdown]
# **Read in the image**

# %%
img = cv2.imread("/flower.jpg")
o_img =cv2.resize(img, (500, 800))
cv2_imshow(o_img)
# Out:
# <PIL.Image.Image image mode=RGB size=500x800 at 0x7FD4C663DE90>

# %% [markdown]
# **Convert image to gray scale**

# %%
gray_image=cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
cv2_imshow(gray_image)

# %% [markdown]
# **Invert the gray scale image**

# %%
inverted_gray_image=255-gray_image
cv2_imshow(inverted_gray_image)

# %% [markdown]
# **Blur the image by gaussian function**

# %%
blurred_img = cv2.GaussianBlur(inverted_gray_image, (21,21), 0)
cv2_imshow(blurred_img)
# Out:
# <PIL.Image.Image image mode=L size=2533x1900 at 0x7FD4C708E750>

# %% [markdown]
# **Invert the blurred image**

# %%
inverted_blurred_image = 255-blurred_img
cv2_imshow(inverted_blurred_image)
# Out:
# <PIL.Image.Image image mode=L size=2533x1900 at 0x7FD4C6689490>

# %% [markdown]
# **Create the pencil sketch image**

# %%
pencil_sketch_image = cv2.divide(gray_image,inverted_blurred_image,scale=256.0)
cv2_imshow(pencil_sketch_image)

# %% [markdown]
# **END OF TASK**
# **THANK YOU !!!**
